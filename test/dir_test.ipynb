# %%
import os
import matplotlib.pyplot as plt
from utils import plt_res
import random

train_loss_list= [random.random() for i in range(10)]
eval_loss_list = [random.random() for i in range(10)]
train_acc_list = [random.random() for i in range(10)]
eval_acc_list = [random.random()for i in range(10)]
learnning_rate_list = [random.random() for i in range(10)]

dir_path = f"res_pic/resnet"
if not os.path.exists(dir_path):
    os.makedirs(dir_path)
plt_res(dir_path,train_loss_list,train_acc_list,eval_loss_list,eval_acc_list,learnning_rate_list)
